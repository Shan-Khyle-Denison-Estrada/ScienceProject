# %%
import splitfolders
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from collections import OrderedDict
from datetime import datetime

# %%
OUTPUT_DIR = "../data/coconut disease/split dataset/"

img_data = {}

# Walk through dataset folder
for folder in os.listdir(OUTPUT_DIR):  # e.g., train / val / test
    subfolder_path = os.path.join(OUTPUT_DIR, folder)
    img_data[folder] = {}
    for subfolder in os.listdir(subfolder_path):  # e.g., each class
        img_data[folder][subfolder] = len(os.listdir(os.path.join(subfolder_path, subfolder)))

# Convert to DataFrame
df = pd.DataFrame.from_dict(img_data, orient='index').T

# Print actual numbers
print("Image distribution (Train / Val / Test per class):")
print(df)

# Plot bar chart
ax = df.plot(kind='bar')
plt.title("Image Counts per Class")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.show()

# Totals per split
print("\nTotal images per split:")
print(df.sum(axis=0))

# Grand total
print("\nTotal images overall:", df.values.sum())
# Out:
# Image distribution (Train / Val / Test per class):
#                    test  train  val
# Bud Root Dropping   100   1935  100
# Bud Rot             100   1935  100
# Gray Leaf Spot      100   1935  100
# Leaf Rot            100   1935  100
# Stem Bleeding       100   1935  100
# Total images per split:
# test      500
# train    9675
# val       500
# dtype: int64
#
# Total images overall: 10675

# %%
# Augmentation
im_size = 224
transformation = transforms.Compose(
            [
                transforms.Resize(256),
                transforms.CenterCrop(im_size),
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
            ])

 # Load data
train_data = datasets.ImageFolder(
    OUTPUT_DIR + "train", transform=transformation
)
val_data = datasets.ImageFolder(
    OUTPUT_DIR + "val", transform=transformation
)
test_data = datasets.ImageFolder(
    OUTPUT_DIR + "test", transform=transformation
)

# Creating data samplers and loaders:
BATCH_SIZE = 32

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, pin_memory=True)

val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=True)

test_loader = DataLoader(
    test_data, batch_size=BATCH_SIZE, shuffle=False
)


# Label mapping
class_mapping = train_data.class_to_idx

# %%
def validation(model, criterion, val_loader, device):
    val_loss = 0.0
    accuracy = 0.0

    model.eval()
    with torch.no_grad():
        for images, labels in iter(val_loader):
            images, labels = images.to(device), labels.to(device)

            output = model(images)
            val_loss += criterion(output, labels).item()

            # Auto-detect log-probs vs logits
            if torch.allclose(torch.exp(output).sum(dim=1), torch.ones(output.size(0)).to(device), atol=1e-3):
                probabilities = torch.exp(output)  # log-probs
            else:
                probabilities = torch.softmax(output, dim=1)  # logits

            equality = labels.data == probabilities.max(dim=1)[1]
            accuracy += equality.type(torch.FloatTensor).mean().item()

    return val_loss, accuracy

# %%
def train_model(model, optimizer, criterion, train_loader, val_loader, epochs=50):
    
    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    device_name = torch.cuda.get_device_name(device) if device.type == "cuda" else "CPU"
    print(f"Using device: {device} -> {device_name}")

    # Move model to device
    model.to(device)

    plot_training_loss = []
    plot_validation_loss = []
    plot_training_acc = []
    plot_validation_acc = []

    num_batches = len(train_loader)

    for e in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for batch_idx, (images, labels) in enumerate(train_loader, 1):
            # Move data to GPU/CPU
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            output = model(images)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Training accuracy batch-wise
            _, preds = torch.max(output, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

            # Show batch progress
            print(
                f"Epoch {e+1}/{epochs} - Batch {batch_idx}/{num_batches} "
                f"- Loss: {loss.item():.4f}",
                end="\r"
            )

        # Training summary
        train_loss = running_loss / num_batches
        train_acc = correct / total

        # Validation phase
        model.eval()
        with torch.no_grad():
            validation_loss, val_acc = validation(model, criterion, val_loader, device)

        val_loss = validation_loss / len(val_loader)
        val_acc = val_acc / len(val_loader)

        # End-of-epoch log
        print(
            f"\nEpoch: {e+1}/{epochs} | "
            f"Training Loss: {train_loss:.3f} | "
            f"Validation Loss: {val_loss:.3f} | "
            f"Training Accuracy: {train_acc:.3f} | "
            f"Validation Accuracy: {val_acc:.3f}"
        )

        # Save history
        plot_training_loss.append(train_loss)
        plot_validation_loss.append(val_loss)
        plot_training_acc.append(train_acc)
        plot_validation_acc.append(val_acc)
    
    # Plot results
    plt.figure(figsize=(12, 5))

    # Loss curve
    plt.subplot(1, 2, 1)
    plt.plot(plot_training_loss, label='Training Loss')
    plt.plot(plot_validation_loss, label='Validation Loss')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    # Accuracy curve
    plt.subplot(1, 2, 2)
    plt.plot(plot_training_acc, label='Training Accuracy')
    plt.plot(plot_validation_acc, label='Validation Accuracy')
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.show()

    return model

# %%
def save_checkpoint(model, class_mapping, arch):
    """
    Save trained model weights.

    Input:
    arch(str): Model architecture
    """

    checkpoint = {
        "arch": arch,
        "class_to_idx": class_mapping,
        "model_state_dict": model.state_dict(),
    }

    timestamp = datetime.now().date().strftime("%Y%m%d")
    torch.save(checkpoint, f"./checkpoint/{timestamp}_{arch}.pth")

# %%
# Load pretrained ResNet50
model = models.resnet50(weights=True)
#model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

# %%
# Freeze all layers
for parameter in model.parameters():
    parameter.requires_grad = False

# %%
print("Original final layer")
print(model.fc)

# Build custom classifier
num_classes = len(class_mapping)
num_ftrs = model.fc.in_features
classifier = nn.Sequential(
    OrderedDict(
        [
            ("fc", nn.Linear(num_ftrs, num_classes)),
            ("output", nn.LogSoftmax(dim=1)),
        ]
    )
)
model.fc = classifier

print("\nModified final layer")
print(model.fc)
# Out:
# Original final layer
# Linear(in_features=2048, out_features=1000, bias=True)
#
# Modified final layer
# Sequential(
#   (fc): Linear(in_features=2048, out_features=5, bias=True)
#   (output): LogSoftmax(dim=1)
# )

# %%
x = np.arange(0.01, 1.0, 0.001)
y = -np.log(x)

fig,ax = plt.subplots(figsize=(6,4))
ax.plot(x,y)
plt.ylabel('-log(x)')
plt.xlabel('x')
plt.title('Negative log-likelihood range')
plt.show()

# %%
# Loss function and gradient descent
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
# Train model
resnet_model = train_model(model, optimizer, criterion, train_loader, val_loader)
# Out:
# Using device: cuda -> NVIDIA GeForce GTX 1660 Ti
# Epoch 1/50 - Batch 303/303 - Loss: 0.1687
# Epoch: 1/50 | Training Loss: 0.246 | Validation Loss: 0.093 | Training Accuracy: 0.931 | Validation Accuracy: 0.977
# Epoch 2/50 - Batch 303/303 - Loss: 0.0328
# Epoch: 2/50 | Training Loss: 0.093 | Validation Loss: 0.065 | Training Accuracy: 0.973 | Validation Accuracy: 0.988
# Epoch 3/50 - Batch 303/303 - Loss: 0.5508
# Epoch: 3/50 | Training Loss: 0.069 | Validation Loss: 0.051 | Training Accuracy: 0.980 | Validation Accuracy: 0.990
# Epoch 4/50 - Batch 303/303 - Loss: 0.0592
# Epoch: 4/50 | Training Loss: 0.055 | Validation Loss: 0.045 | Training Accuracy: 0.984 | Validation Accuracy: 0.992
# Epoch 5/50 - Batch 303/303 - Loss: 0.1272
# Epoch: 5/50 | Training Loss: 0.048 | Validation Loss: 0.045 | Training Accuracy: 0.986 | Validation Accuracy: 0.990
# Epoch 41/50 - Batch 303/303 - Loss: 0.0135
# Epoch: 41/50 | Training Loss: 0.016 | Validation Loss: 0.060 | Training Accuracy: 0.995 | Validation Accuracy: 0.986
# Epoch 42/50 - Batch 303/303 - Loss: 0.2927
# Epoch: 42/50 | Training Loss: 0.017 | Validation Loss: 0.061 | Training Accuracy: 0.994 | Validation Accuracy: 0.992
# Epoch 43/50 - Batch 303/303 - Loss: 0.0004
# Epoch: 43/50 | Training Loss: 0.013 | Validation Loss: 0.061 | Training Accuracy: 0.995 | Validation Accuracy: 0.985
# Epoch 44/50 - Batch 303/303 - Loss: 0.0323
# Epoch: 44/50 | Training Loss: 0.013 | Validation Loss: 0.066 | Training Accuracy: 0.995 | Validation Accuracy: 0.988
# Epoch 45/50 - Batch 303/303 - Loss: 0.0154
# Epoch: 45/50 | Training Loss: 0.015 | Validation Loss: 0.058 | Training Accuracy: 0.994 | Validation Accuracy: 0.989
# Epoch 46/50 - Batch 303/303 - Loss: 0.0031
# Epoch: 46/50 | Training Loss: 0.017 | Validation Loss: 0.060 | Training Accuracy: 0.994 | Validation Accuracy: 0.988
# Epoch 47/50 - Batch 303/303 - Loss: 0.0158
# Epoch: 47/50 | Training Loss: 0.015 | Validation Loss: 0.076 | Training Accuracy: 0.995 | Validation Accuracy: 0.990
# Epoch 48/50 - Batch 303/303 - Loss: 0.0011
# Epoch: 48/50 | Training Loss: 0.012 | Validation Loss: 0.073 | Training Accuracy: 0.996 | Validation Accuracy: 0.988
# Epoch 49/50 - Batch 303/303 - Loss: 0.0085
# Epoch: 49/50 | Training Loss: 0.015 | Validation Loss: 0.107 | Training Accuracy: 0.995 | Validation Accuracy: 0.987
# Epoch 50/50 - Batch 303/303 - Loss: 0.0304
# Epoch: 50/50 | Training Loss: 0.015 | Validation Loss: 0.068 | Training Accuracy: 0.994 | Validation Accuracy: 0.987

# %%
save_checkpoint(resnet_model, class_mapping, 'resnet50')

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

def test_model(model, test_loader, class_names=None, use_log_probs=True):
    device = next(model.parameters()).device  # Get model's device
    model.eval()

    predictions = []
    true_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            output = model(images)

            # If using NLLLoss (LogSoftmax), exponentiate
            if use_log_probs:
                probabilities = torch.exp(output)
            else:
                probabilities = output  # raw logits for CrossEntropyLoss

            preds = probabilities.argmax(dim=1)
            predictions.extend(preds.cpu().tolist())
            true_labels.extend(labels.cpu().tolist())

    # Determine label set
    unique_labels = sorted(set(true_labels) | set(predictions))
    if class_names is None:
        class_names = [f"Class_{i}" for i in unique_labels]
    
    # Get classification report as dict
    report_dict = classification_report(
        true_labels,
        predictions,
        target_names=class_names if class_names else None,
        output_dict=True,
        digits=4
    )

    # Extract only weighted avg + accuracy
    summary = {
        "precision": report_dict["weighted avg"]["precision"],
        "recall": report_dict["weighted avg"]["recall"],
        "f1-score": report_dict["weighted avg"]["f1-score"],
        "accuracy": report_dict["accuracy"]
    }

    print("\nSummary Metrics:")
    for k, v in summary.items():
        print(f"{k:10}: {v:.4f}")

    # Confusion Matrix
    cm = confusion_matrix(true_labels, predictions, labels=unique_labels)

    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()

# %%
class_names = test_loader.dataset.classes
test_model(resnet_model, test_loader, class_names=class_names, use_log_probs=True)
# Out:
# Summary Metrics:
# precision : 0.9960
# recall    : 0.9960
# f1-score  : 0.9960
# accuracy  : 0.9960
